# %% [markdown]
# <a href="https://colab.research.google.com/github/harishy0406/TruthLens-AI/blob/main/Fake_News.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **TruthLens-AI**
# *An Attention-Enhanced FakeBert Framework for AI-Generated Fake News*

# %% [markdown]
# ## **Importing Libraries**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Models**

# %% [markdown]
# ### **Bi-LSTM**

# %% [markdown]
# ### **FakeBert**

# %%
#
