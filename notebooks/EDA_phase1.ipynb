# %% [markdown]
# # Dataset Preview

# %%
import pandas as pd
df = pd.read_csv("../data/raw/news_dataset_raw.csv")
df.head()
# Out:
# C:\Users\hariv\AppData\Local\Temp\ipykernel_29168\2778279939.py:2: DtypeWarning: Columns (0: post_id, 1: platform, 2: timestamp, 3: time, 4: month, 5: weekday, 6: country, 7: city, 8: timezone, 9: author_id, 10: model_signature, 11: factcheck_verdict) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../data/raw/news_dataset_raw.csv")
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# ...

# %% [markdown]
# ## Check distribution

# %%
df["label"].value_counts()
# Out:
# label
# 0.0    23481
# 1.0    21417
# Name: count, dtype: int64
